# %% [markdown]
# # Machine Learning
# ## Lab Session 2 -  Data Preprocessing
# ## Topic: Data Understanding, Cleaning, normalization, slicing and Feature Engineering
# ## Dataset: Titanic (Structured Data)

# %% [markdown]
# ## 1 PROBLEM STATEMENT
#
# """
# Problematic Statement:
# Predict whether a passenger survived the Titanic disaster .
#
# Task Type:
# Binary Classification
#
# Objective:
# Learn a function f(x) that maps passenger features -> survival label.
# """

# %% [markdown]
# Step 1 — Data Understanding (EDA)
# Step 2 — Data Cleaning
# Step 3 — Data Splitting
# Step 4 — Data Transformation
# Step 5 — Visualization

# %% [markdown]
# ## 2 IMPORT LIBRARIES
# **matplotlib**
# **pandas**

# %%
# Importlibraries
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 3 LOAD DATA
# - <u>Question:</u> Use a "pandas" methode to load the csv file, in order to store the data in a data frame?

# %% [markdown]
# ## 4 DATASET DESCRIPTION
# """
# Attributes Description:
# - Survived: Target (0 = No, 1 = Yes)
# - Pclass: Ticket class (1,2,3)
# - Sex: Gender (male/female)
# - Age: Age in years
# - SibSp: # siblings/spouses aboard
# - Parch: # parents/children aboard
# - Fare: Ticket fare/Price
# - Embarked: Port of embarkation
#
# - <u>Question:</u> Use a slicing technique to input features and Target?
# X: All except 'Survived'
# y: Survived

# %% [markdown]
# ## DATA UNDERSTANDING
#
# <u>Questions:</u>
# - get a quick look at your data structure and values by displaying the first rows of your DataFrame?
# - Prints a summary of the DataFrame?
# - Generates statistical summaries of the DataFrame?

# %% [markdown]
# ## DATA UNDERSTANDING
#
# <u>Questions:</u> display the data type of each column in your DataFrame?

# %% [markdown]
# Questions:
# 1. Which features are numerical?
# 2. Which features are categorical?
# 3. Are there missing values?

# %% [markdown]
# ## Data Preprocessing: DATA Cleaning + Transformation (Normalization / Encoding) + Dimesion Reduction

# %% [markdown]
# ### Pclass Attribute

# %% [markdown]
# Inspect Pclass Values

# %%
# Display sorted unique values (cleaner visualization)
print("Sorted unique values:")
print(sorted(df['Pclass'].unique()))
# Out:
# Sorted unique values:
# [np.int64(1), np.int64(2), np.int64(3)]

# %% [markdown]
# Frequency of Each Class
# - <u>Questions:</u>
# Count how many passengers belong to each class?
# Visualize distribution of passenger classes using matplotlib?

# %%
# Count how many passengers belong to each class

# %%
# Visualize distribution of passenger classes

# %% [markdown]
# - <u>Question:</u> What do you observe at this level?

# %% [markdown]
# ### Name Attribute

# %% [markdown]
# Inspect the Name Attribute
# - <u>Question:</u> Display sample names?

# %%
# Display sample names
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %% [markdown]
# What observations can you make at this stage regarding the dataset?

# %%
# Number of unique names


# Total number of rows
# Out:
# Number of unique names: 891
# Total number of rows: 891

# %% [markdown]
# What do you notice?

# %%
# Compute length of each name


# Summary statistics
# Out:
# count    891.000000
# mean      26.965208
# std        9.281607
# min       12.000000
# 25%       20.000000
# 50%       25.000000
# 75%       30.000000
# max       82.000000
# Name: Name_length, dtype: float64

# %% [markdown]
# - <u>Question:</u> Plot the distribution of name length?

# %%
# Sort names by length (descending)


# Display top 10 longest names
# Out:
#                                                                                    Name  Name_length
# 307  Penasco y Castellana, Mrs. Victor de Satode (Maria Josefa Perez de Soto y Vallejo)           82
# 427                 Phillips, Miss. Kate Florence ("Mrs Kate Louise Phillips Marshall")           67
# 556                   Duff Gordon, Lady. (Lucille Christiana Sutherland) ("Mrs Morgan")           65
# 670                       Brown, Mrs. Thomas William Solomon (Elizabeth Catherine Ford)           61
# 610                           Andersson, Mrs. Anders Johan (Alfrida Konstantia Brogren)           57
# 25                            Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)           57
# 759                            Rothes, the Countess. of (Lucy Noel Martha Dyer-Edwards)           56
# 41                             Turpin, Mrs. William John Robert (Dorothy Ann Wonnacott)           56
# 319                            Spedden, Mrs. Frederic Oakley (Margaretta Corning Stone)           56
# 85                              Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)           55

# %%
# loads the built-in regular expressions module


# Extract titles using regex


# Show unique titles 'Mr', 'Mrs', 'Miss', ...

# %%
# Count occurrences of each title

# %%
# Horizontal version of Titles

# %%
# Get top 10 most frequent titles
# Out:
# Top 10 titles:
# Index(['Mr', 'Miss', 'Mrs', 'Master', 'Dr', 'Rev', 'Col', 'Mlle', 'Major',
#        'Ms'],
#       dtype='object', name='Title_raw')

# %%
# define a function to remove titles from Name




# Apply the transformation to remove titles from Name


# Display comparison (Name and cleaned_Name colomns)
# Out:
#                                                 Name  \
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry
# 5                                   Moran, Mr. James
# 6                            McCarthy, Mr. Timothy J
# 7                     Palsson, Master. Gosta Leonard
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                Nasser, Mrs. Nicholas (Adele Achem)
#
#                                        Name_clean
# 0                             Braund, Owen Harris
# 1  Cumings, John Bradley (Florence Briggs Thayer)
# 2                                Heikkinen, Laina
# 3         Futrelle, Jacques Heath (Lily May Peel)
# 4                            Allen, William Henry
# 5                                    Moran, James
# 6                             McCarthy, Timothy J
# 7                          Palsson, Gosta Leonard
# 8    Johnson, Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Nicholas (Adele Achem)

# %%
# Before cleaning
df['Name_length'] = df['Name'].apply(len)

# After cleaning
df['Name_clean_length'] = df['Name_clean'].apply(len)

# print statistical summaries to compare both
# Out:
# Before cleaning:
# count    891.000000
# mean      26.965208
# std        9.281607
# min       12.000000
# 25%       20.000000
# 50%       25.000000
# 75%       30.000000
# max       82.000000
# Name: Name_length, dtype: float64
#
# After cleaning:
# count    891.000000
# mean      22.248036
# std        9.157804
# min        8.000000
# 25%       15.000000
# 50%       21.000000
# 75%       26.000000
# max       77.000000
# Name: Name_clean_length, dtype: float64

# %%
# uses Matplotlib to compare the distribution of name lengths before and after cleaning.

# %% [markdown]
# At this stage, we have explored several text cleaning transformations. However, for this task, it is preferable to drop the Name attribute, as it behaves like an identifier: each instance has a unique value and does not provide useful information for prediction.

# %%
# Drop the name column

# %%
# Display the names of all columns in your DataFrame
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Name_length', 'Title_raw',
#        'Name_clean', 'Name_clean_length'],
#       dtype='object')

# %% [markdown]
# ### Question: Remove all extra columns and keep only the ones we selected.

# %% [markdown]
# ##### Sex Attribute

# %% [markdown]
# ### Question: Display :
#              -- unique values for the Sex attribute.
#              -- First 10 raw values for the Sex column
#              -- Statistics related to each class (rates, graph)
#              -- What do you remark ?

# %%
# Out:
# array(['male', 'female'], dtype=object)

# %%
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# 5      male
# 6      male
# 7      male
# 8    female
# 9    female
# Name: Sex, dtype: object

# %%
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
# Out:
# Sex
# male      64.758698
# female    35.241302
# Name: proportion, dtype: float64

# %%
# compute survival rates by gender.
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %% [markdown]
# #### Question: Interpretation?

# %% [markdown]
# ##### One-hot encoding for Sex Attribute

# %%
# Encode: male = 0, female = 1

# %%
#display of head values: gender attribute
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Sex, dtype: int64

# %% [markdown]
# ### Question: Aplly encoding using the following rule: male: 1 , female : 0.

# %% [markdown]
# ### Age Attribute

# %% [markdown]
# #### Question: Display current existing columns in your dataset

# %%
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Name_length', 'Title_raw',
#        'Name_clean', 'Name_clean_length'],
#       dtype='object')

# %% [markdown]
# #### Question: Display head values for the Age attribute (first 10 values)

# %%
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: Age, dtype: float64

# %% [markdown]
# #### Question : What do you remark?

# %%
#check column data type
print(df['Age'].dtype)
# Out:
# float64

# %%
#count missing/empty values, isna stands for 'is not available'
# Out:
# np.int64(177)

# %%
#print the rate of missing values
# Out:
# Percentage of missing values: 19.87%

# %%
# Save where Age is missing
missing_mask = df['Age'].isna() #not runing before

# %% [markdown]
# **Decision**: Why NOT drop rows?

# %% [markdown]
# ##### Median Imputation

# %% [markdown]
# Missing values in the Age attribute can be filled using the median of the entire column. This approach is simple and robust to outliers, as the median is not affected by extreme values

# %%
#age attribute: median imputation

# %%
#verification
#Display Only Originally Missing Values (After Imputation)
# Out:
#     Age_med
# 5      28.0
# 17     28.0
# 19     28.0
# 26     28.0
# 28     28.0
# 29     28.0
# 31     28.0
# 32     28.0
# 36     28.0
# 42     28.0

# %% [markdown]
# Group-Based Imputation

# %% [markdown]
# A more advanced approach consists of imputing missing Age values based on groups defined by relevant features such as Sex and Pclass. This method replaces missing values with the median Age of similar passengers, leading to more accurate and context-aware estimations.

# %%
df['Age'] = df.groupby(['Sex', 'Pclass'])['Age'].transform(
    lambda x: x.fillna(x.median())
)

# %%
#verification
#Display Only Originally Missing Values (After Imputation)
# Out:
#      Age
# 5   25.0
# 17  30.0
# 19  21.5
# 26  25.0
# 28  21.5
# 29  25.0
# 31  35.0
# 32  21.5
# 36  25.0
# 42  25.0

# %% [markdown]
# #### Question: Plot the function f(Age), where f denotes the frequency (number of individuals) corresponding to each age value.

# %% [markdown]
# #### Question: what you have remarked on this ghraph?

# %% [markdown]
# Categorisation of people based on the age value.
# Classes are the following:
#                  -- young: age < 18
#                  -- adult: 18 ≤ age < 60
#                  -- older: age ≥ 60

# %%
# Create "AgeGroup" colomn for age categories



# Display first rows of Age and AgeGroup to verify
# Out:
#     Age AgeGroup
# 0  22.0    Adult
# 1  38.0    Adult
# 2  26.0    Adult
# 3  35.0    Adult
# 4  35.0    Adult
# 5  25.0    Adult
# 6  54.0    Adult
# 7   2.0    Young
# 8  27.0    Adult
# 9  14.0    Young

# %%
# Encode age groups

# %%
# Display result
# Out:
#     Age AgeGroup Age_group_encoded
# 0  22.0    Adult                 2
# 1  38.0    Adult                 2
# 2  26.0    Adult                 2
# 3  35.0    Adult                 2
# 4  35.0    Adult                 2
# 5  25.0    Adult                 2
# 6  54.0    Adult                 2
# 7   2.0    Young                 1
# 8  27.0    Adult                 2
# 9  14.0    Young                 1

# %% [markdown]
# Visualize the 3 classes: Statistics

# %% [markdown]
# <u>Questions:</u>
# - Is there a class imbalance in the Age feature distribution?
# - What is the impact of this imbalance?

# %% [markdown]
# #### Question: Make:
#                 -- Encode:     'Child' :1,'Teen' :2, 'YoungAdult' :3, 'Adult' :4, 'Senior' :5 (create new column)
#                 -- Display the first 10 values of the age column after transformation
#                 -- Dispaly the distribution of age groups
#                 -- what you not at this stage

# %% [markdown]
# What is next?

# %%
print(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Name_length', 'Title_raw',
#        'Name_clean', 'Name_clean_length', 'Age_med', 'AgeGroup',
#        'Age_group_encoded'],
#       dtype='object')

# %% [markdown]
# ### SibSp Attribute

# %% [markdown]
# Question: -- display the data type of SibSp
#           -- Check if there are any empty values

# %%
# Out:
# dtype('int64')

# %%
# Out:
# <bound method Series.count of 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: SibSp, Length: 891, dtype: bool>

# %% [markdown]
# #### Question: Write a Python script to visualize the function
# 𝑓(𝑥=SibSp), where 𝑓(𝑥) represents the frequency (number of passengers) having a given number of siblings/spouses (SibSp). Choose a horizontal bar representation.

# %% [markdown]
# Question: What do you observe? Can we group categories with small frequencies?

# %% [markdown]
# ### Parch Attribute

# %% [markdown]
# #### Question: Similarily, display:
#               -- data type of the Parch attribute
#               -- verify if it exists empty values in you dataset
#               -- display the rate of empty values (if existing)
#               -- plot the graph f(x=Parch), f: number of passengers (barh representation)

# %%
# Out:
# dtype('int64')

# %%
# Out:
# 0.0

# %%
# Out:
# Text(0.5, 1.0, 'Frequency distribution of Parch')

# %% [markdown]
# We can reduce the dimensionality of the input feature space by introducing a new attribute, FamilySize, defined as:
# FamilySize = SibSp + Parch + 1 (1 : the passenger), which serves as a **data reduction** step

# %% [markdown]
# ### FamilySize Attribute

# %%
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1

# %%
print(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Name_length', 'Title_raw',
#        'Name_clean', 'Name_clean_length', 'Age_med', 'AgeGroup',
#        'Age_group_encoded', 'FamilySize'],
#       dtype='object')

# %%
#display header values
# Out:
#    SibSp  Parch  FamilySize
# 0      1      0           2
# 1      1      0           2
# 2      0      0           1
# 3      1      0           2
# 4      0      0           1

# %% [markdown]
# #### Question: Similarily, display:
#               -- plot the graph f(x=FamilySize), f: number of passengers (barh representation)

# %%
# Out:
# Text(0.5, 1.0, 'Frequency distribution of FamilySize')

# %% [markdown]
# #### Question: What should we do at this stage? What do you suggest as a categorization based on family size?

# %%
# Out:
#    FamilySize FamilyGroup
# 0           2       Small
# 1           2       Small
# 2           1       Alone
# 3           2       Small
# 4           1       Alone
# 5           1       Alone
# 6           1       Alone
# 7           5         Big
# 8           3       Small
# 9           2       Small

# %% [markdown]
# #### Question: Encoding
#                        -- Apply the following mapping:
#                        Familysize= 1 : Alone
#                        Familysize= 2 or 3 : small
#                        Familysize= >3 : big
#
#                        --Display head values

# %%
# Out:
#    FamilySize FamilyGroup FamilyGroup_encoded
# 0           2       Small                   2
# 1           2       Small                   2
# 2           1       Alone                   1
# 3           2       Small                   2
# 4           1       Alone                   1
# 5           1       Alone                   1
# 6           1       Alone                   1
# 7           5         Big                   3
# 8           3       Small                   2
# 9           2       Small                   2

# %% [markdown]
# #### Question: Similarily, display:
#               -- plot the graph f(x=FamilySize), f: number of passengers (barh representation). (After encoding)

# %%
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Name_length', 'Title_raw',
#        'Name_clean', 'Name_clean_length', 'Age_med', 'AgeGroup',
#        'Age_group_encoded', 'FamilySize', 'FamilyGroup',
#        'FamilyGroup_encoded'],
#       dtype='object')

# %%
# Out:
# Text(0.5, 1.0, 'Frequency distribution of FamilySize')

# %% [markdown]
# What do you observe about the distribution of passengers based on family size before and after applying encoding?

# %%
#print the df columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Name_length', 'Title_raw',
#        'Name_clean', 'Name_clean_length', 'Age_med', 'AgeGroup',
#        'Age_group_encoded', 'FamilySize', 'FamilyGroup',
#        'FamilyGroup_encoded'],
#       dtype='object')

# %% [markdown]
# ### Ticket Attribute

# %%
#print the ticket colomn type
# Out:
# object

# %%
#print the ticket head
# Out:
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# 5              330877
# 6               17463
# 7              349909
# 8              347742
# 9              237736
# Name: Ticket, dtype: object

# %%
# Count and print rows where Ticket contains at least one letter


# Print the rate
# Out:
# 230
# 25.813692480359148

# %% [markdown]
# <u>Question:</u> Comment and add an intepretation of this rate?

# %%
#number of unique ticket value
# Out:
# 681

# %%
#print the rate of unique ticket values
# Out:
# Unique ticket rate: 76.43097643097643

# %% [markdown]
# #### Question: What is your interpretation of the provided result? what action can we do?

# %%
print(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Name_length', 'Title_raw',
#        'Name_clean', 'Name_clean_length', 'Age_med', 'AgeGroup',
#        'Age_group_encoded', 'FamilySize', 'FamilyGroup',
#        'FamilyGroup_encoded'],
#       dtype='object')

# %% [markdown]
# ### Fare Attribute

# %% [markdown]
# #### Question: Similarily, display:
#               -- data type pf the Fare attribute
#               -- verify if it exists empty values in you dataset
#               -- display the rate of empty values (if existing)
#               -- plot the graph f(x=Fare), f: number of passengers (line representation)

# %%
# Out:
# float64

# %%
# Out:
# 0

# %%
# Out:
# Text(0.5, 1.0, 'Frequency distribution of Fare/ticket Price')

# %% [markdown]
# Max/min Normalization

# %%
#loads sklearn preprocessing

# scale the Fare column between 0 and 1.

# %%
#plot
# Out:
# Text(0.5, 1.0, 'Frequency distribution of Fare/ticket Price')

# %%
# standardize the Fare column using Z-score normalization

# %%
#plot
# Out:
# Text(0.5, 1.0, 'Frequency distribution of Fare/ticket Price')

# %% [markdown]
# What observations can you make? Which normalization method is most appropriate for our dataset, or do both methods have similar effects?

# %% [markdown]
# ### Cabin Attribute

# %% [markdown]
# #### Question: Similarily, display:
#               -- data type pf the Parch attribute
#               -- verify if there are empty values in you dataset
#               -- display the rate of empty values (if existing)
#               -- plot the graph f(x=Cabin), f: number of passengers (barh representation)

# %%
# Out:
# object

# %%
# Out:
# 687
# 77.10437710437711

# %% [markdown]
# #### Question: Remove the Cabin column from your dataset (Data cleaning) Verify that this feature was removed from your dataset.

# %%
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Embarked', 'Name_length', 'Title_raw', 'Name_clean',
#        'Name_clean_length', 'Age_med', 'AgeGroup', 'Age_group_encoded',
#        'FamilySize', 'FamilyGroup', 'FamilyGroup_encoded', 'Fare_minmax',
#        'Fare_zscore'],
#       dtype='object')

# %% [markdown]
# ### Embarked Attribute

# %% [markdown]
# #### Question: Similarily, display:
#               -- data type pf the Parch attribute
#               -- verify if it exists empty values in you dataset
#               -- display the rate of empty values (if existing)
#               -- display the first 10 values of embarked feature

# %%
# Out:
# object

# %%
# Out:
# 2
# 0.22446689113355783

# %% [markdown]
# #### Question: Write a Python script to impute missing values in the Embarked column based on Pclass groups. Display head (10) and unique values of Embarked attribute.

# %%
# Out:
# ['S' 'C' 'Q']

# %% [markdown]
# #### Question: Encode: S : 1, C: 2, Q: 3, Display before and after encoding

# %%
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object 0      1
# 1      2
# 2      1
# 3      1
# 4      1
#       ..
# 886    1
# 887    1
# 888    1
# 889    2
# 890    3
# Name: Embarked_encoded, Length: 891, dtype: int64

# %% [markdown]
# #### Question: Similarily, display:
#               -- plot the graph f(x=Embarked), f: number of passengers (barh representation). (After encoding)

# %%
# Out:
# Text(0.5, 1.0, 'Frequency distribution of Embarked CLasses')

# %% [markdown]
# #### Question: Display the first 10 raws of your dataset after all applied preprocessing steps. Remember:

# %%
columns = [
    'Survived','Pclass', 'Sex', 'Ticket',
    'Age_group_encoded', 'FamilyGroup_encoded',
    'Embarked_encoded', 'Fare_zscore'
]

print(df[columns].head(10))
# Out:
#    Survived  Pclass  Sex            Ticket Age_group_encoded  \
# 0         0       3    0         A/5 21171                 2
# 1         1       1    1          PC 17599                 2
# 2         1       3    1  STON/O2. 3101282                 2
# 3         1       1    1            113803                 2
# 4         0       3    0            373450                 2
# 5         0       3    0            330877                 2
# 6         0       1    0             17463                 2
# 7         0       3    0            349909                 1
# 8         1       3    1            347742                 2
# 9         1       2    1            237736                 1
#
#   FamilyGroup_encoded  Embarked_encoded  Fare_zscore
# 0                   2                 1    -0.502445
# 1                   2                 2     0.786845
# 2                   1                 1    -0.488854
# 3                   2                 1     0.420730
# 4                   1                 1    -0.486337
# 5                   1                 3    -0.478116
# 6                   1                 1     0.395814
# 7                   3                 1    -0.224083
# 8                   2                 1    -0.424256
# 9                   2                 2    -0.042956

# %%
columns = [
    'Survived', 'Pclass', 'Sex',
    'Age_group_encoded', 'FamilyGroup_encoded',
    'Embarked_encoded', 'Fare_zscore'
]

# %%
corr_matrix = df[columns].corr()
print(corr_matrix)
# Out:
#                      Survived    Pclass       Sex  Age_group_encoded  \
# Survived             1.000000 -0.338481  0.543351          -0.114684
# Pclass              -0.338481  1.000000 -0.131900          -0.169063
# Sex                  0.543351 -0.131900  1.000000          -0.138114
# Age_group_encoded   -0.114684 -0.169063 -0.138114           1.000000
# FamilyGroup_encoded  0.134197 -0.054495  0.289929          -0.348310
# Embarked_encoded     0.106811  0.045702  0.116569           0.023084
# Fare_zscore          0.257307 -0.549500  0.182333           0.008969
#
#                      FamilyGroup_encoded  Embarked_encoded  Fare_zscore
# Survived                        0.134197          0.106811     0.257307
# Pclass                         -0.054495          0.045702    -0.549500
# Sex                             0.289929          0.116569     0.182333
# Age_group_encoded              -0.348310          0.023084     0.008969
# FamilyGroup_encoded             1.000000         -0.049327     0.273618
# Embarked_encoded               -0.049327          1.000000     0.062142
# Fare_zscore                     0.273618          0.062142     1.000000

# %%
# Print the correlation matrix, use colorbar

# %%
# Scatter (cloud)
# create a scatter plot showing the relationship between age group and fare (standardized)

# %% [markdown]
# Outlier Removal

# %%
# outliers detection
# identify outliers in the Fare column using Z-scores.


# print these outliers

# %%
# create a cleaned version of the dataset by removing extreme outliers in Fare

# %%
# Scatter (cloud)
# create a new scatter plot showing the relationship between age group and fare after removing outliers.
